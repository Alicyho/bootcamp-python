# %%
print("10 + 3 =", 10 + 3)
print("9 - 10 =", 9 - 10)
print("10 * 3 =", 10 * 3)
print("5 / 2 =", 5 / 2)
print("10 / 3 =", 10 / 3)
# Out:
# 10 + 3 = 13
# 9 - 10 = -1
# 10 * 3 = 30
# 5 / 2 = 2.5
# 10 / 3 = 3.3333333333333335

# %%
print("10 / 0 =", 10 / 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print("10 / 0 =", 10 / 0)
#
# ZeroDivisionError: division by zero

# %%
print("\nThe course's name is \"Enterprise System Development x Data Engineering\"")
# Out:
# The course's name is "Enterprise System Development x Data Engineering"
